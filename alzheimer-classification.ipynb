# %% [markdown]
# ### 1. Installing dependencies

# %%
import pathlib
import numpy as np
import random
import matplotlib.pyplot as plt
import os
import pandas as pd
import tensorflow as tf

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2. Getting the data from directory

# %%
file_path = './Dataset'
data_dir = pathlib.Path(file_path)
class_names = np.array(sorted([item.name for item in data_dir.glob('*')]))
print(class_names)
# Out:
# ['Mild_Demented' 'Moderate_Demented' 'Non_Demented' 'Very_Mild_Demented']

# %% [markdown]
# ### 3. Visualizing random images with labels from the data

# %%
plt.figure(figsize=(20, 20)) 
for i in range(16):
    ax = plt.subplot(4, 4, i+1)
    random_class = random.randint(0, 3)
    folder_path = file_path + '/' + class_names[random_class]
    random_image_path = folder_path + '/' + (random.sample(os.listdir(folder_path), 1)[0])
    image = plt.imread(random_image_path)
    plt.axis('off')
    plt.title(class_names[random_class], fontsize = 15, fontweight = 'bold')
    plt.imshow(image)

# %% [markdown]
# ### 4. Preparing the dataset for building CNN

# %%
SEED = 1   # maybe can do with random seed generator and compare results with different seed values in the future.
BATCH_SIZE = 32
IMG_SIZE = (128, 128)

X_train = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed = SEED,
    image_size = IMG_SIZE,
    batch_size = BATCH_SIZE,
    validation_split = 0.2,
    subset = 'training'
)

X_validation = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    seed = SEED,
    image_size = IMG_SIZE,
    batch_size = BATCH_SIZE,
    validation_split = 0.2,
    subset = 'validation'
)
# Out:
# Found 6400 files belonging to 4 classes.
# Using 5120 files for training.
# Found 6400 files belonging to 4 classes.
# Using 1280 files for validation.

# %% [markdown]
# ### 5. Building the model

# %%
INPUT_SHAPE = IMG_SIZE + (3,)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Rescaling(scale=1./255, input_shape=INPUT_SHAPE))
model.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Dropout(0.20))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(4, activation = 'softmax'))

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  dropout (Dropout)           (None, 16, 16, 64)        0
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 2121380 (8.09 MB)
# Trainable params: 2121380 (8.09 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 6. Fitting the model

# %%
history = model.fit(X_train, epochs = 50, validation_data=X_validation, verbose=1)
# Out:
# Epoch 1/50
# 160/160 [==============================] - 63s 336ms/step - loss: 0.9635 - accuracy: 0.5354 - val_loss: 0.8591 - val_accuracy: 0.5922
# Epoch 2/50
# 160/160 [==============================] - 42s 264ms/step - loss: 0.7591 - accuracy: 0.6617 - val_loss: 0.6747 - val_accuracy: 0.6969
# Epoch 3/50
# 160/160 [==============================] - 42s 262ms/step - loss: 0.5358 - accuracy: 0.7680 - val_loss: 0.5400 - val_accuracy: 0.7508
# Epoch 4/50
# 160/160 [==============================] - 47s 294ms/step - loss: 0.3440 - accuracy: 0.8574 - val_loss: 0.2783 - val_accuracy: 0.9023
# Epoch 5/50
# 160/160 [==============================] - 52s 324ms/step - loss: 0.2047 - accuracy: 0.9271 - val_loss: 0.2245 - val_accuracy: 0.9180
# Epoch 6/50
# 160/160 [==============================] - 42s 259ms/step - loss: 0.1516 - accuracy: 0.9418 - val_loss: 0.1941 - val_accuracy: 0.9328
# Epoch 7/50
# 160/160 [==============================] - 42s 260ms/step - loss: 0.0938 - accuracy: 0.9697 - val_loss: 0.1660 - val_accuracy: 0.9422
# Epoch 8/50
# 160/160 [==============================] - 42s 262ms/step - loss: 0.0960 - accuracy: 0.9637 - val_loss: 0.1371 - val_accuracy: 0.9617
# Epoch 9/50
# 160/160 [==============================] - 43s 267ms/step - loss: 0.0539 - accuracy: 0.9826 - val_loss: 0.0636 - val_accuracy: 0.9797
# Epoch 10/50
# 160/160 [==============================] - 42s 261ms/step - loss: 0.0388 - accuracy: 0.9885 - val_loss: 0.0624 - val_accuracy: 0.9766
# Epoch 11/50
# 160/160 [==============================] - 41s 255ms/step - loss: 0.0414 - accuracy: 0.9857 - val_loss: 0.1161 - val_accuracy: 0.9641
# Epoch 12/50
# 160/160 [==============================] - 40s 252ms/step - loss: 0.0237 - accuracy: 0.9918 - val_loss: 0.1634 - val_accuracy: 0.9492
# Epoch 13/50
ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0567 - val_accuracy: 0.9844
# Epoch 36/50
# 160/160 [==============================] - 39s 241ms/step - loss: 0.0192 - accuracy: 0.9932 - val_loss: 0.1358 - val_accuracy: 0.9688
# Epoch 37/50
# 160/160 [==============================] - 38s 240ms/step - loss: 0.0105 - accuracy: 0.9967 - val_loss: 0.1150 - val_accuracy: 0.9758
# Epoch 38/50
# 160/160 [==============================] - 39s 242ms/step - loss: 0.0180 - accuracy: 0.9957 - val_loss: 0.0799 - val_accuracy: 0.9812
# Epoch 39/50
# 160/160 [==============================] - 40s 252ms/step - loss: 0.0083 - accuracy: 0.9969 - val_loss: 0.0732 - val_accuracy: 0.9844
# Epoch 40/50
# 160/160 [==============================] - 42s 260ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 0.0835 - val_accuracy: 0.9781
# Epoch 41/50
# 160/160 [==============================] - 43s 270ms/step - loss: 0.0205 - accuracy: 0.9941 - val_loss: 0.2300 - val_accuracy: 0.9414
# Epoch 42/50
# 160/160 [==============================] - 44s 274ms/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.1053 - val_accuracy: 0.9758
# Epoch 43/50
# 160/160 [==============================] - 44s 275ms/step - loss: 0.0327 - accuracy: 0.9895 - val_loss: 0.0745 - val_accuracy: 0.9758
# Epoch 44/50
# 160/160 [==============================] - 3075s 19s/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 0.0652 - val_accuracy: 0.9828
# Epoch 45/50
# 160/160 [==============================] - 43s 265ms/step - loss: 0.0057 - accuracy: 0.9977 - val_loss: 0.1123 - val_accuracy: 0.9789
# Epoch 46/50
# 160/160 [==============================] - 40s 248ms/step - loss: 0.0254 - accuracy: 0.9924 - val_loss: 0.0540 - val_accuracy: 0.9836
# Epoch 47/50
# 160/160 [==============================] - 41s 256ms/step - loss: 0.0108 - accuracy: 0.9959 - val_loss: 0.0894 - val_accuracy: 0.9805
# Epoch 48/50
# 160/160 [==============================] - 41s 254ms/step - loss: 0.0204 - accuracy: 0.9922 - val_loss: 0.1493 - val_accuracy: 0.9648
# Epoch 49/50
# 160/160 [==============================] - 40s 253ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.0345 - val_accuracy: 0.9922
# Epoch 50/50
# 160/160 [==============================] - 43s 268ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 0.0271 - val_accuracy: 0.9914

# %% [markdown]
# ### 7. Model evaluation

# %%
model_evaluate = model.evaluate(X_validation)
print("Accuracy: %", "{:.2f}".format(model_evaluate[1]*100))
print("Loss: %", "{:.2f}".format(model_evaluate[0]*100))
# Out:
# 40/40 [==============================] - 3s 75ms/step - loss: 0.0926 - accuracy: 0.9680
# Accuracy: % 96.80
# Loss: % 9.26

# %%
df = pd.DataFrame(history.history)
ax = df.plot(figsize=(10,5), lw=3, grid='on')
ax.set_title('History per Epoch', fontsize=18, fontweight='bold')
ax.set_xlabel('Epochs', fontsize=15, fontweight='bold')
ax.plot()
# Out:
# []

# %%
plt.figure(figsize=(20, 20))
for image, label in X_validation.take(1): 
    for i in range(16):
        ax = plt.subplot(4, 4, i+1)
        img = image[i].numpy().astype("uint8")
        img = tf.expand_dims(img, axis=0)
        predicted_class = np.argmax(model.predict(img))
        plt.axis('off')
        plt.title("True Label: " + class_names[label[i]]+'\n', fontsize=12, style='italic', color='blue', loc='center')
        plt.title("Predicted Label: " + class_names[predicted_class], fontsize=12, fontweight='bold', color='green', loc='right')
        plt.imshow(image[i].numpy().astype("uint8"))
# Out:
# 1/1 [==============================] - 1s 625ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
